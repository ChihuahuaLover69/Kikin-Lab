# %%
#https://www.kaggle.com/datasets/saitejabandaruin/imdb-top-700-movies-2026-edition/data?select=IMDb_Top_700_Movies_2026.csv

# %%
import kaggle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import kaggle
#
# ModuleNotFoundError: No module named 'kaggle'
